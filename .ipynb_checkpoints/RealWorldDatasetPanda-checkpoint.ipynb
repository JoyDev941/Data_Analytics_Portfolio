# %%
import pandas as pd

# %%
df = pd.read_excel('archive/olympics-data.xlsx').head(11)

# %%
df
# Out:
#     athlete_id                     name   born_date          born_city  \
# 0            1    Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
#
#              born_region born_country     NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# You can filter a data frame to hold specific information from your existing dataset. In the following example, I filtered and made a dataframe about the names of the athletes.

# %%
dfName = df.name
dfName
# Out:
# 0       Jean-François Blanchy
# 1              Arnaud Boetsch
# 2                Jean Borotra
# 3             Jacques Brugnon
# 4                Albert Canet
# 5           Nicolas Chatelain
# 6               Patrick Chila
# 7                Henri Cochet
# 8               Marcel Cousin
# 9          Guy de la Chapelle
# 10    Élie, Comte de Lastours
# Name: name, dtype: object

# %% [markdown]
# You can make the filter with multiple columns and store it by adding a {$DataFrameName}[[]]

# %%
dfName = df[["name", "born_country", "born_region", "born_city", "born_date"]]

# %%
dfName
# Out:
#                        name born_country           born_region  \
# 0     Jean-François Blanchy          FRA               Gironde
# 1            Arnaud Boetsch          FRA              Yvelines
# 2              Jean Borotra          FRA  Pyrénées-Atlantiques
# 3           Jacques Brugnon          FRA                 Paris
# 4              Albert Canet          GBR               England
# 5         Nicolas Chatelain          FRA                 Somme
# 6             Patrick Chila          FRA               Essonne
# 7              Henri Cochet          FRA                 Rhône
# 8             Marcel Cousin          FRA                  Gard
# 9        Guy de la Chapelle          FRA                  Cher
# 10  Élie, Comte de Lastours          FRA              Yvelines
#
#             born_city   born_date
# 0            Bordeaux  1886-12-12
# 1              Meulan  1969-04-01
# 2            Biarritz  1898-08-13
# 3         Paris VIIIe  1895-05-11
# ...

# %% [markdown]
# you can make a filter by doing a statement, example is date larger than "1990-01-01"?
# the output is weather the statement is true or false.

# %%
dfName["born_date"] > "1900-01-01"
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# Name: born_date, dtype: bool

# %% [markdown]
# This section is to filter and show only athletes who are born after 1900.

# %%
df['born_date'] = pd.to_datetime(df['born_date'], errors='coerce') #convert the data type of the column to date
df1990 = df[df["born_date"] > "1900-01-01"]

df1990
# Out:
#    athlete_id               name  born_date     born_city born_region  \
# 1           2     Arnaud Boetsch 1969-04-01        Meulan    Yvelines
# 5           6  Nicolas Chatelain 1970-01-13        Amiens       Somme
# 6           7      Patrick Chila 1969-11-27   Ris-Orangis     Essonne
# 7           8       Henri Cochet 1901-12-14  Villeurbanne       Rhône
#
#   born_country     NOC  height_cm  weight_kg   died_date
# 1          FRA  France      183.0       76.0         NaN
# 5          FRA  France      181.0       70.0         NaN
# 6          FRA  France      180.0       73.0         NaN
# 7          FRA  France        NaN        NaN  1987-04-02

# %% [markdown]
# This filters only French athletes.

# %%
dfCountry = df[df["born_country"] == "FRA"]
dfCountry
# Out:
#     athlete_id                     name  born_date          born_city  \
# 0            1    Jean-François Blanchy 1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch 1969-04-01             Meulan
# 2            3             Jean Borotra 1898-08-13           Biarritz
# 3            4          Jacques Brugnon 1895-05-11        Paris VIIIe
# 5            6        Nicolas Chatelain 1970-01-13             Amiens
# 6            7            Patrick Chila 1969-11-27        Ris-Orangis
# 7            8             Henri Cochet 1901-12-14       Villeurbanne
# 8            9            Marcel Cousin 1896-08-04              Nîmes
# 9           10       Guy de la Chapelle 1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours 1874-08-12            Orgeval
#
#              born_region born_country     NOC  height_cm  weight_kg  \
# 0                Gironde          FRA  France        NaN        NaN
# ...
