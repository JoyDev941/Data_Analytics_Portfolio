# %%
import pandas as pd

# %%
df = pd.read_excel('archive/olympics-data.xlsx').head(11)

# %%
df
# Out:
#     athlete_id                     name   born_date          born_city  \
# 0            1    Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
#
#              born_region born_country     NOC  height_cm  weight_kg  \
# ...

# %%
dfName = df.name
dfName
# Out:
# 0       Jean-François Blanchy
# 1              Arnaud Boetsch
# 2                Jean Borotra
# 3             Jacques Brugnon
# 4                Albert Canet
# 5           Nicolas Chatelain
# 6               Patrick Chila
# 7                Henri Cochet
# 8               Marcel Cousin
# 9          Guy de la Chapelle
# 10    Élie, Comte de Lastours
# Name: name, dtype: object

# %%
dfName = df[["name", "born_country", "born_region", "born_city", "born_date"]]

# %%
dfName
# Out:
#                        name born_country           born_region  \
# 0     Jean-François Blanchy          FRA               Gironde
# 1            Arnaud Boetsch          FRA              Yvelines
# 2              Jean Borotra          FRA  Pyrénées-Atlantiques
# 3           Jacques Brugnon          FRA                 Paris
# 4              Albert Canet          GBR               England
# 5         Nicolas Chatelain          FRA                 Somme
# 6             Patrick Chila          FRA               Essonne
# 7              Henri Cochet          FRA                 Rhône
# 8             Marcel Cousin          FRA                  Gard
# 9        Guy de la Chapelle          FRA                  Cher
# 10  Élie, Comte de Lastours          FRA              Yvelines
#
#             born_city   born_date
# 0            Bordeaux  1886-12-12
# 1              Meulan  1969-04-01
# 2            Biarritz  1898-08-13
# 3         Paris VIIIe  1895-05-11
# ...

# %%
dfName["born_date"] > "1900-01-01"
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# Name: born_date, dtype: bool

# %%
dfName[dfName["born_country"].isin("FRA")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 dfName[dfName["born_country"].isin("FRA")]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:5570, in Series.isin(self, values)
#    5497 def isin(self, values) -> Series:
#    5498     """
#    5499     Whether elements in Series are contained in `values`.
#    5500
#    (...)   5568     dtype: bool
#    5569     """
# -> 5570     result = algorithms.isin(self._values, values)
#    5571     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5572         self, method="isin"
#    5573     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\algorithms.py:477, in isin(comps, values)
#     472     raise TypeError(
#     473         "only list-like objects are allowed to be passed "
# ...
