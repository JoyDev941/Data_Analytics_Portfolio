# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyDev941/Data_Analytics_Portfolio/blob/main/LearningPandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
df.sort_values(["Units Sold", "Coffee Type"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %% [markdown]
# You can iterate trhough your dataset, but its not always recommended as pandas have better performance, in iteration.

# %%
for index, row in df.iterrows():
    print(index)
    print(row["Coffee Type":"Units Sold"])
    print(" ")
# Out:
# 0
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
# 1
# Coffee Type    Latte
# Units Sold        15
# Name: 1, dtype: object
#
# 2
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
# 3
# Coffee Type    Latte
# Units Sold        20
# Name: 3, dtype: object
#
# 4
# Coffee Type    Espresso
# Units Sold           35
# Name: 4, dtype: object
#
# 5
# Coffee Type    Latte
# Units Sold        25
# Name: 5, dtype: object
#
# 6
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
# 7
# Coffee Type    Latte
# Units Sold        30
# Name: 7, dtype: object
#
# 8
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
# 9
# Coffee Type    Latte
# Units Sold        35
# Name: 9, dtype: object
#
# 10
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
# 11
# Coffee Type    Latte
# Units Sold        35
# Name: 11, dtype: object
#
# 12
# Coffee Type    Espresso
# ...
